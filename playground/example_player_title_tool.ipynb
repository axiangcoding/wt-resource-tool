# %%
from wt_resource_tool import WTPlayerTitleTool

player_title_tool = WTPlayerTitleTool()

# if you can't access github, you can use github-jsdelivr
await player_title_tool.load_data(source="github")

# %%
await player_title_tool.get_game_version()
# Out:
# '2.44.0.42'

# %%
await player_title_tool.get_title("title_god_of_war")
# Out:
# PlayerTitleDesc(id='title_god_of_war', english='God of War', russian='Бог войны', chinese='战争教父', comments='', max_chars='')
