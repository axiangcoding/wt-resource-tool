# %%
import os

from dotenv import load_dotenv

load_dotenv()

local_repo_path = os.environ["DATAMINE_REPO_PATH"]

# %%
from wt_resource_tool.parser.vehicle_data_parser import parse_vehicle_data

vehicle_data = parse_vehicle_data(local_repo_path, read_model_info=True)
# Out:
# 2025-11-15 17:46:25.778 | INFO     | wt_resource_tool.parser.vehicle_data_parser:parse_vehicle_data:97 - Reading model info for 3144 vehicles using thread pool
# 2025-11-15 17:46:30.902 | INFO     | wt_resource_tool.parser.vehicle_data_parser:parse_vehicle_data:111 - Processed 1000/3144 vehicles
# 2025-11-15 17:46:30.906 | INFO     | wt_resource_tool.parser.vehicle_data_parser:parse_vehicle_data:111 - Processed 2000/3144 vehicles
# 2025-11-15 17:46:30.910 | INFO     | wt_resource_tool.parser.vehicle_data_parser:parse_vehicle_data:111 - Processed 3000/3144 vehicles
# 2025-11-15 17:46:30.952 | INFO     | wt_resource_tool.parser.vehicle_data_parser:parse_vehicle_data:115 - Completed reading model info for all 3144 vehicles

# %%
vinfo = vehicle_data.get_vehicle_by_id("z_10me")

# %%
if vinfo:
    print(vinfo.vehicle_id)
    print(vinfo.flight_model)
# Out:
# z_10me
# model='z_10me' have_ccip_for_rocket=True have_ccrp_for_rocket=False
